# %% [markdown]
# # Sample Notebook
#
# This is a sample notebook for testing.

# %%
x = 1 + 1
print(x)
# Out:
# 2
# 2

# %% [markdown]
# ## Section Two
#
# More text here.

# %%
import os
print(os.getcwd())
